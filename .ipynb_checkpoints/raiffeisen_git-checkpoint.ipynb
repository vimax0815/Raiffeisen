# %% [markdown]
# ## Оглавление<a id="heading"></a>
# 1. [Ознакомление с данными](#1)
# 2. [Обработка колонок](#2)
# 3. [Генерация признаков](#3)
# 4. [Важность признаков](#4)
# 5. [Прогнозирование таргета](#5)

# %% [markdown]
# ##  1. Ознакомление с данными<a id="1"></a>
# [Обработка колонок с текстом▼](#2) [Оглавление▲▲](#heading)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

import catboost
from catboost import CatBoostRegressor

import shap
shap.initjs()

import re

from IPython.core.interactiveshell import InteractiveShell    
InteractiveShell.ast_node_interactivity = "all"  

pd.options.display.max_columns=500        
pd.options.display.max_rows=1000     

plt.style.use('ggplot')
from pylab import rcParams
rcParams['figure.figsize']=(20, 5)
import warnings; warnings.filterwarnings(action='ignore')
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %%
path = '/home/user/Рабочий стол/диск D/Проекты/хакатон raiffeisen/data/'
train = pd.read_csv(f'{path}train.csv')
test = pd.read_csv(f'{path}test.csv')
train.shape, test.shape
train_1 = train.copy()
test_1 = test.copy()
train.head(1)
test.head(1)
# Out:
# ((279792, 77), (2974, 76))
#     city floor     id        lat        lng  osm_amenity_points_in_0.001  \
# 0  Пермь   NaN  COL_0  57.998207  56.292797                            4
#
#    osm_amenity_points_in_0.005  osm_amenity_points_in_0.0075  \
# 0                           19                            35
#
#    osm_amenity_points_in_0.01  osm_building_points_in_0.001  \
# 0                          52                             0
#
#    osm_building_points_in_0.005  osm_building_points_in_0.0075  \
# 0                             0                              0
#
#    osm_building_points_in_0.01  osm_catering_points_in_0.001  \
# 0                            0                             0
#
#    osm_catering_points_in_0.005  osm_catering_points_in_0.0075  \
# 0                             2                              4
#
#    osm_catering_points_in_0.01  osm_city_closest_dist osm_city_nearest_name  \
# 0                            6                3.29347                 Пермь
#
#    osm_city_nearest_population  osm_crossing_closest_dist  \
# 0                    1055397.0                   0.027732
#
#    osm_crossing_points_in_0.001  osm_crossing_points_in_0.005  \
# 0                             3                             6
#
#    osm_crossing_points_in_0.0075  osm_crossing_points_in_0.01  \
# 0                             17                           34
#
#    osm_culture_points_in_0.001  osm_culture_points_in_0.005  \
# 0                            0                            0
#
#    osm_culture_points_in_0.0075  osm_culture_points_in_0.01  \
# 0                             1                           1
#
#    osm_finance_points_in_0.001  osm_finance_points_in_0.005  \
# 0                            0                            0
#
#    osm_finance_points_in_0.0075  osm_finance_points_in_0.01  \
# 0                             1                           2
#
#    osm_healthcare_points_in_0.005  osm_healthcare_points_in_0.0075  \
# 0                               2                                3
#
#    osm_healthcare_points_in_0.01  osm_historic_points_in_0.005  \
# 0                              4                             0
#
#    osm_historic_points_in_0.0075  osm_historic_points_in_0.01  \
# 0                              0                            1
#
#    osm_hotels_points_in_0.005  osm_hotels_points_in_0.0075  \
# 0                           0                            0
#
#    osm_hotels_points_in_0.01  osm_leisure_points_in_0.005  \
# 0                          0                            0
#
#    osm_leisure_points_in_0.0075  osm_leisure_points_in_0.01  \
# 0                             1                           2
#
#    osm_offices_points_in_0.001  osm_offices_points_in_0.005  \
# 0                            0                            1
#
#    osm_offices_points_in_0.0075  osm_offices_points_in_0.01  \
# 0                             2                           4
#
#    osm_shops_points_in_0.001  osm_shops_points_in_0.005  \
# 0                          4                         11
#
#    osm_shops_points_in_0.0075  osm_shops_points_in_0.01  \
# 0                          20                        28
#
#    osm_subway_closest_dist  osm_train_stop_closest_dist  \
# 0               269.024986                     3.368385
#
#    osm_train_stop_points_in_0.005  osm_train_stop_points_in_0.0075  \
# 0                               0                                0
#
#    osm_train_stop_points_in_0.01  osm_transport_stop_closest_dist  \
# 0                              0                         0.002864
#
#    osm_transport_stop_points_in_0.005  osm_transport_stop_points_in_0.0075  \
# 0                                   4                                   13
#
#    osm_transport_stop_points_in_0.01  per_square_meter_price  \
# 0                                 21                139937.5
#
#    reform_count_of_houses_1000  reform_count_of_houses_500  \
# 0                          136                          49
#
#    reform_house_population_1000  reform_house_population_500  \
# 0                        2503.0                        765.0
#
#    reform_mean_floor_count_1000  reform_mean_floor_count_500  \
# 0                      5.762963                     5.530612
#
#    reform_mean_year_building_1000  reform_mean_year_building_500  \
# 0                     1964.118519                    1960.959184
#
#           region  total_square  street        date  realty_type  price_type
# 0  Пермский край          32.0  S27289  2020-01-05           10           0
#     city floor          id  osm_amenity_points_in_0.001  \
# 0  Курск   1.0  COL_289284                            7
#
#    osm_amenity_points_in_0.005  osm_amenity_points_in_0.0075  \
# 0                           55                            85
#
#    osm_amenity_points_in_0.01  osm_building_points_in_0.001  \
# 0                         117                             0
#
#    osm_building_points_in_0.005  osm_building_points_in_0.0075  \
# 0                             0                              0
#
#    osm_building_points_in_0.01  osm_catering_points_in_0.001  \
# 0                            0                             0
#
#    osm_catering_points_in_0.005  osm_catering_points_in_0.0075  \
# 0                             2                              6
#
#    osm_catering_points_in_0.01  osm_city_closest_dist osm_city_nearest_name  \
# 0                           10               4.101661                 Курск
#
#    osm_city_nearest_population  osm_crossing_closest_dist  \
# 0                     443212.0                   0.147072
#
#    osm_crossing_points_in_0.001  osm_crossing_points_in_0.005  \
# 0                             0                             7
#
#    osm_crossing_points_in_0.0075  osm_crossing_points_in_0.01  \
# 0                              7                           19
#
#    osm_culture_points_in_0.001  osm_culture_points_in_0.005  \
# 0                            0                            0
#
#    osm_culture_points_in_0.0075  osm_culture_points_in_0.01  \
# 0                             0                           0
#
#    osm_finance_points_in_0.001  osm_finance_points_in_0.005  \
# 0                            1                            2
#
#    osm_finance_points_in_0.0075  osm_finance_points_in_0.01  \
# 0                             3                           3
#
#    osm_healthcare_points_in_0.005  osm_healthcare_points_in_0.0075  \
# 0                               5                                5
#
#    osm_healthcare_points_in_0.01  osm_historic_points_in_0.005  \
# 0                              5                             2
#
#    osm_historic_points_in_0.0075  osm_historic_points_in_0.01  \
# 0                              2                            4
#
#    osm_hotels_points_in_0.005  osm_hotels_points_in_0.0075  \
# 0                           7                            7
#
#    osm_hotels_points_in_0.01  osm_leisure_points_in_0.005  \
# 0                          8                            0
#
#    osm_leisure_points_in_0.0075  osm_leisure_points_in_0.01  \
# 0                             0                           1
#
#    osm_offices_points_in_0.001  osm_offices_points_in_0.005  \
# 0                            0                            0
#
#    osm_offices_points_in_0.0075  osm_offices_points_in_0.01  \
# 0                             0                           1
#
#    osm_shops_points_in_0.001  osm_shops_points_in_0.005  \
# 0                          5                         36
#
#    osm_shops_points_in_0.0075  osm_shops_points_in_0.01  \
# 0                          61                        83
#
#    osm_subway_closest_dist  osm_train_stop_closest_dist  \
# 0               435.363535                     5.636811
#
#    osm_train_stop_points_in_0.005  osm_train_stop_points_in_0.0075  \
# 0                               0                                0
#
#    osm_train_stop_points_in_0.01  osm_transport_stop_closest_dist  \
# 0                              0                         0.108668
#
#    osm_transport_stop_points_in_0.005  osm_transport_stop_points_in_0.0075  \
# 0                                  11                                   15
#
#    osm_transport_stop_points_in_0.01  reform_count_of_houses_1000  \
# 0                                 27                          184
#
#    reform_count_of_houses_500  reform_house_population_1000  \
# 0                          78                        1997.0
#
#    reform_house_population_500  reform_mean_floor_count_1000  \
# 0                        743.0                         4.325
#
#    reform_mean_floor_count_500  reform_mean_year_building_1000  \
# 0                     4.211268                     1966.471591
#
#    reform_mean_year_building_500           region        lat        lng  \
# 0                     1966.74026  Курская область  51.709255  36.147908
#
#    total_square street        date  realty_type  price_type
# 0    156.148996  S6983  2020-09-06          100           1

# %% [markdown]
# #### выберем из всей тренировочной выборки только данные с экспертной оценкой

# %%
train = train[train['price_type']==1]
train.shape
# Out:
# (4493, 77)

# %%
df = pd.concat([train, test])
df.rename(columns={'per_square_meter_price':'target'}, inplace=True)
mask = df['target'].notnull()

# %%
df_nan = pd.DataFrame(df.loc[:, df.isna().any()].isna().sum().sort_values(ascending=False), columns=['NaN count'])
df_nan['NaN %'] =  df_nan.apply(lambda x: round(x * 100 / len(df), 3))
df_nan
# Out:
#                                 NaN count   NaN %
# floor                                3765  50.422
# target                               2974  39.829
# reform_mean_floor_count_500           126   1.687
# reform_mean_year_building_500         124   1.661
# reform_house_population_500           116   1.554
# reform_mean_floor_count_1000           98   1.312
# reform_mean_year_building_1000         96   1.286
# reform_house_population_1000           90   1.205
# street                                 23   0.308
# osm_city_nearest_population             1   0.013

# %% [markdown]
# ##  2. Обработка колонок<a id="2"></a>
# [Первичный отбор признаков▼](#3) [Оглавление▲▲](#heading)

# %%
df['street'].unique()
df['street'] = df['street'].fillna('A')
# Out:
# array(['S5845', 'S27968', 'S23597', ..., 'S30314', 'S8521', 'S34005'],
#       dtype=object)

# %%
df['region'].replace('Алтай', 'Алтайский край', inplace=True)
df['floor'] = df['floor'].str.lower()
df['floor'].unique()
# Out:
# array([nan, '2.0', '1', '-1.0', '1.0', '3.0', '18.0', 'подвал, 1', '2',
#        '4.0', 'подвал', 'цоколь, 1', '1,2,антресоль', '5.0', '6.0',
#        'цоколь', '9.0', '4', '5', 'тех.этаж (6)', '3', '10',
#        'фактически на уровне 1 этажа', '6', '1,2,3', '1, подвал',
#        '1,2,3,4', '1,2', '1,2,3,4,5', '5, мансарда', '-2.0', '10.0',
#        '1-й, подвал', '12', '15', '13', '1, подвал, антресоль', '16.0',
#        'мезонин', 'подвал, 1-3', '8', '7', '15.0', '1 (цокольный этаж)',
#        '3, мансарда (4 эт)', 'подвал,1', '1, антресоль', '1-3',
#        'мансарда (4эт)', '1, 2.', '9', '7.0', 'подвал , 1 ', '1, 2',
#        'подвал, 1,2,3', '0.0', '1 + подвал (без отделки)', 'мансарда',
#        '2,3', '4, 5', '1-й, 2-й', '18', '1 этаж, подвал', '17.0',
#        '1, цоколь', 'подвал, 1-7, техэтаж', '3 (антресоль)', '1, 2, 3',
#        'цоколь, 1,2(мансарда)', 'подвал, 3. 4 этаж', 'подвал, 1-4 этаж',
#        'подва, 1.2 этаж', '2, 3', '-1', '1.2', '11', '36', '7,8',
#        '1 этаж', '1-й', '3 этаж', '4 этаж', '5 этаж', 'подвал,1,2,3,4,5',
#        '29', 'подвал, цоколь, 1 этаж', '3, мансарда', '11.0', '12.0',
#        'цоколь, 1, 2,3,4,5,6', ' 1, 2, антресоль',
#        '3 этаж, мансарда (4 этаж)', 'цокольный', '1,2 ', '14', '3,4',
#        'подвал, 1 и 4 этаж', '5(мансарда)', 'технический этаж,5,6',
#        ' 1-2, подвальный', '1, 2, 3, мансардный', '8.0',
#        'подвал, 1, 2, 3', '1,2,3, антресоль, технический этаж', '3, 4',
#        '1-3 этажи, цоколь (188,4 кв.м), подвал (104 кв.м)',
#        '1,2,3,4, подвал', '2-й', '1, 2 этаж', 'подвал, 1, 2', '1-7',
#        '1 (по док-м цоколь)', '1,2,подвал ', '13.0', 'подвал, 2',
#        'подвал,1,2,3', '1,2,3 этаж, подвал', '2, 3, 4, тех.этаж',
#        'цокольный, 1,2', 'техническое подполье'], dtype=object)

# %%
floor_1 = ['фактически на уровне 1 этажа', '1 этаж', '1 (по док-м цоколь)', '1-й', '1', '1.0']
floor_2 = ['подвал, 1', 'цоколь, 1', '1,2,антресоль', '1,2,3', '1, подвал', '1,2,3,4', '1,2', '1,2,3,4,5',
          '1-й, подвал', '1, подвал, антресоль', 'подвал, 1-3', 'подвал,1', '1, антресоль', '1-3', 
           'подвал , 1 ', '1, 2', 'подвал, 1,2,3', '1 + подвал (без отделки)', '1-й, 2-й', '1 этаж, подвал', 
           '1, цоколь', 'подвал, 1-7, техэтаж', '1, 2, 3', 'цоколь, 1,2(мансарда)', 'подвал, 1-4 этаж', 
           'подва, 1.2 этаж', '1.2', 'подвал,1,2,3,4,5', 'подвал, цоколь, 1 этаж', 'цоколь, 1, 2,3,4,5,6', 
           ' 1, 2, антресоль', '1,2', 'подвал, 1 и 4 этаж', ' 1-2, подвальный', '1, 2, 3, мансардный', 
           'подвал, 1, 2, 3', '1,2,3, антресоль, технический этаж', '1-7', '1,2,подвал ','1, 2 этаж', 
           '1-3 этажи, цоколь (188,4 кв.м), подвал (104 кв.м)', '1,2,3,4, подвал', 'подвал, 1, 2', 'подвал,1,2,3',
           '1,2,3 этаж, подвал', 'цокольный, 1,2', '1,2 ', '1, 2.']
floor_цоколь = ['цоколь', '1 (цокольный этаж)', 'цокольный', '0', '0.0']
floor_подвал = ['подвал', '-1', 'техническое подполье', '-1.0', '-1', '-2.0']
floor_multy = ['5, мансарда', '3, мансарда (4 эт)', '2,3', '4, 5', 'подвал, 3. 4 этаж', '2, 3', '7,8',  
               '3, мансарда', '3 этаж, мансарда (4 этаж)', '3,4', 'технический этаж,5,6', '3, 4', 'подвал, 2', 
               '2, 3, 4, тех.этаж']
floor_high = ['тех.этаж (6)', 'мансарда (4эт)', '3 (антресоль)', '3 этаж', '4 этаж', '5 этаж',
              '5(мансарда)', '3.0', '18.0', '4.0', '5.0', '6.0', '9.0', '4', '5', '3', '10', '6', '10.0', '12', 
              '15', '13', '16.0', '8', '7', '15.0', '9', '7.0', '18', '17.0', '11', '36', '29', '11.0', '12.0', 
              '14', '8.0', '13.0', 'мезонин', 'мансарда', '2-й', '2.0', '2']

# %%
df['floor'] = ['A' if i in floor_1 else i for i in df['floor']]
df['floor'] = ['B' if i in floor_2 else i for i in df['floor']]
df['floor'] = ['C' if i in floor_цоколь else i for i in df['floor']]
df['floor'] = ['D' if i in floor_подвал else i for i in df['floor']]
df['floor'] = ['E' if i in floor_multy else i for i in df['floor']]
df['floor'] = ['F' if i in floor_high else i for i in df['floor']]
df['floor'] = df['floor'].fillna('G')

# %%
df['realty_type'].unique()
df.loc[df['realty_type'] == 10, 'realty_type'] = 'A'
df.loc[df['realty_type'] == 100, 'realty_type'] = 'B'
df.loc[df['realty_type'] == 110, 'realty_type'] = 'C'
# Out:
# array([110,  10, 100])

# %%
df['city'].nunique()
df['city'] = df['city'].apply(lambda x: re.sub('[^A-ZА-Яа-яa-z0-9_]+', '', x))
df['osm_city_nearest_name'] = df['osm_city_nearest_name'].apply(lambda x: re.sub('[^A-ZА-Яа-яa-z0-9_]+', '', x))
df['region'] = df['region'].apply(lambda x: re.sub('[^A-ZА-Яа-яa-z0-9_]+', '', x))
# Out:
# 238

# %%
a = pd.DataFrame(df['city'].value_counts()).reset_index()
a.shape
# Out:
# (238, 2)

# %%
a.plot(kind='line', y='city')
plt.xticks(rotation=90);

# %% [markdown]
# #### уберем из данных города с маленьким количеством объектов недвижимости к продаже

# %%
a = a[a['city'] < 10]['index'].to_list()
df['city'] = df['city'].apply(lambda x: 'A' if x in a else x)

# %%
missing = ['reform_mean_floor_count_500',
           'reform_mean_year_building_500', 
           'reform_house_population_500',
           'reform_mean_floor_count_1000',
           'reform_mean_year_building_1000',
           'reform_house_population_1000']

for feat in missing:
    df[feat] = df.groupby("city")[feat].transform(lambda x: x.fillna(x.median()))
    df[feat] = df[feat].fillna(df[feat].median())

df['osm_city_nearest_population'].fillna(df['osm_city_nearest_population'].min(), inplace=True)
df.drop(['id', 'date', 'lng', 'lat', 'price_type'], axis=1, inplace=True)

# %% [markdown]
# #### посмотрим на зависимость цен на недвижимость от площади объекта и обрежем выбросы

# %%
sns.scatterplot('total_square', 'target', data=df);
df['total_square'] = df['total_square'].apply(lambda x: 9000 if x>9000 else x)
# Out:
# <AxesSubplot:xlabel='total_square', ylabel='target'>

# %% [markdown]
# ##  3. Генерация признаков<a id="3"></a>
# [Важность признаков▼](#4) [Оглавление▲▲](#heading)

# %% [markdown]
# #### предпалагая, что цена на недвижимость сильно зависит от площади сгененируем новые признаки, группируя данные по городам, регионам и типам недвижимости

# %%
group_city = df.groupby('city')['total_square'].agg({'mean', 'max', 'min'}).reset_index()

def group_feat_city(row):
    c = row['city'] 
    row['mean_group_city'] = group_city.loc[group_city['city']==c, 'mean'].iloc[0]
    row['min_group_city'] = group_city.loc[group_city['city']==c, 'min'].iloc[0]
    row['max_group_city'] = group_city.loc[group_city['city']==c, 'max'].iloc[0]
    return row

df = df.apply(lambda x: group_feat_city(x), axis=1)

df['total/mean_square_city'] = df['total_square'] / df['mean_group_city']

# %%
group_reg = df.groupby('region')['total_square'].agg({'mean', 'max', 'min'}).reset_index()

def group_feat_reg(row):
    r = row['region'] 
    row['mean_group_reg'] = group_reg.loc[group_reg['region']==r, 'mean'].iloc[0]
    row['min_group_reg'] = group_reg.loc[group_reg['region']==r, 'min'].iloc[0]
    row['max_group_reg'] = group_reg.loc[group_reg['region']==r, 'max'].iloc[0]
    return row

df = df.apply(lambda x: group_feat_reg(x), axis=1)

df['total/mean_square_reg'] = df['total_square'] / df['mean_group_reg']

# %%
group_type = df.groupby('realty_type')['total_square'].agg({'mean', 'max', 'min'}).reset_index()

def group_feat_type(row):
    t = row['realty_type'] 
    row['mean_group_type'] = group_type.loc[group_type['realty_type']==t, 'mean'].iloc[0]
    row['min_group_type'] = group_type.loc[group_type['realty_type']==t, 'min'].iloc[0]
    row['max_group_type'] = group_type.loc[group_type['realty_type']==t, 'max'].iloc[0]
    return row

df = df.apply(lambda x: group_feat_type(x), axis=1)

df['total/mean_square_type'] = df['total_square'] / df['mean_group_type']

# %%
df.shape
df.head(2)
# Out:
# (7467, 84)
#               city floor  osm_amenity_points_in_0.001  \
# 275299  Красноярск     G                            0
# 275300     Саратов     G                           13
#
#         osm_amenity_points_in_0.005  osm_amenity_points_in_0.0075  \
# 275299                            7                            14
# 275300                          198                           345
#
#         osm_amenity_points_in_0.01  osm_building_points_in_0.001  \
# 275299                          26                             0
# 275300                         462                             0
#
#         osm_building_points_in_0.005  osm_building_points_in_0.0075  \
# 275299                             0                              0
# 275300                             0                              0
#
#         osm_building_points_in_0.01  osm_catering_points_in_0.001  \
# 275299                            0                             0
# 275300                            0                             4
#
#         osm_catering_points_in_0.005  osm_catering_points_in_0.0075  \
# 275299                             0                              0
# 275300                            44                             66
#
#         osm_catering_points_in_0.01  osm_city_closest_dist  \
# 275299                            2               7.795659
# 275300                           89               0.987160
#
#        osm_city_nearest_name  osm_city_nearest_population  \
# 275299            Красноярск                    1095286.0
# 275300               Саратов                     842097.0
#
#         osm_crossing_closest_dist  osm_crossing_points_in_0.001  \
# 275299                   0.041323                             2
# 275300                   0.144936                             0
#
#         osm_crossing_points_in_0.005  osm_crossing_points_in_0.0075  \
# 275299                             6                             25
# 275300                             4                             34
#
#         osm_crossing_points_in_0.01  osm_culture_points_in_0.001  \
# 275299                           35                            0
# 275300                           59                            0
#
#         osm_culture_points_in_0.005  osm_culture_points_in_0.0075  \
# 275299                            0                             0
# 275300                            1                             6
#
#         osm_culture_points_in_0.01  osm_finance_points_in_0.001  \
# 275299                           2                            0
# 275300                           9                            0
#
#         osm_finance_points_in_0.005  osm_finance_points_in_0.0075  \
# 275299                            1                             2
# 275300                           13                            22
#
#         osm_finance_points_in_0.01  osm_healthcare_points_in_0.005  \
# 275299                           3                               0
# 275300                          27                               7
#
#         osm_healthcare_points_in_0.0075  osm_healthcare_points_in_0.01  \
# 275299                                0                              0
# 275300                               17                             27
#
#         osm_historic_points_in_0.005  osm_historic_points_in_0.0075  \
# 275299                             0                              0
# 275300                             4                              7
#
#         osm_historic_points_in_0.01  osm_hotels_points_in_0.005  \
# 275299                            1                           0
# 275300                            9                           2
#
#         osm_hotels_points_in_0.0075  osm_hotels_points_in_0.01  \
# 275299                            0                          0
# 275300                            5                          7
#
#         osm_leisure_points_in_0.005  osm_leisure_points_in_0.0075  \
# 275299                            1                             1
# 275300                           11                            16
#
#         osm_leisure_points_in_0.01  osm_offices_points_in_0.001  \
# 275299                           1                            0
# 275300                          20                            1
#
#         osm_offices_points_in_0.005  osm_offices_points_in_0.0075  \
# 275299                            0                             0
# 275300                           11                            21
#
#         osm_offices_points_in_0.01  osm_shops_points_in_0.001  \
# 275299                           0                          0
# 275300                          28                          8
#
#         osm_shops_points_in_0.005  osm_shops_points_in_0.0075  \
# 275299                          5                          10
# 275300                        125                         218
#
#         osm_shops_points_in_0.01  osm_subway_closest_dist  \
# 275299                        15                 1.087101
# 275300                       286               357.425239
#
#         osm_train_stop_closest_dist  osm_train_stop_points_in_0.005  \
# 275299                     2.281425                               0
# 275300                     1.924421                               0
#
#         osm_train_stop_points_in_0.0075  osm_train_stop_points_in_0.01  \
# 275299                                0                              0
# 275300                                0                              0
#
#         osm_transport_stop_closest_dist  osm_transport_stop_points_in_0.005  \
# 275299                         0.052809                                   7
# 275300                         0.045451                                  22
#
#         osm_transport_stop_points_in_0.0075  \
# 275299                                   15
# 275300                                   34
#
#         osm_transport_stop_points_in_0.01         target  \
# 275299                                 21  103120.697310
# 275300                                 45   24874.371004
#
#         reform_count_of_houses_1000  reform_count_of_houses_500  \
# 275299                           95                          31
# 275300                          502                         104
#
#         reform_house_population_1000  reform_house_population_500  \
# 275299                        2670.0                        940.0
# 275300                        4886.0                        943.0
#
#         reform_mean_floor_count_1000  reform_mean_floor_count_500  \
# 275299                      7.136842                     7.612903
# 275300                      4.144608                     4.164557
#
#         reform_mean_year_building_1000  reform_mean_year_building_500  \
# 275299                     1976.684211                    1980.483871
# 275300                     1940.591549                    1939.348837
#
#                     region  total_square  street realty_type  mean_group_city  \
# 275299    Красноярскийкрай    106.351104   S5845           C       309.585190
# 275300  Саратовскаяобласть    175.039602  S27968           A       273.455334
#
#         min_group_city  max_group_city  total/mean_square_city  \
# 275299        5.840220     8081.034585                0.343528
# 275300       14.977634     1622.896787                0.640103
#
#         mean_group_reg  min_group_reg  max_group_reg  total/mean_square_reg  \
# 275299      307.998704       5.840220    8081.034585               0.345297
# 275300      269.592184      14.977634    1622.896787               0.649276
#
#         mean_group_type  min_group_type  max_group_type  \
# 275299       453.587238        5.845197          9000.0
# 275300       360.990435        5.734575          9000.0
#
#         total/mean_square_type
# 275299                0.234467
# 275300                0.484887

# %% [markdown]
# ##  4. Важность признаков<a id="4"></a>
# [Прогнозирование таргета▼](#5) [Оглавление▲▲](#heading)

# %%
y = np.log(df.loc[mask, 'target'])
y_shap = df.loc[mask, 'target']
df = df.drop('target', axis=1)
cat_col = df.select_dtypes(include=['object']).columns.to_list()
num_col = df.select_dtypes(exclude=['object']).columns.to_list()

# %%
X = df[mask]
X.shape, y.shape, y_shap.shape
# Out:
# ((4493, 83), (4493,), (4493,))

# %%
model = CatBoostRegressor(random_state=42)
model.fit(X, y_shap, cat_col, verbose=False)

# %%
explainer = shap.Explainer(model)
shap_values = explainer(X)

# %%
shap.plots.bar(shap_values, max_display=100)

# %%
imp = pd.DataFrame(abs(shap_values.values), columns=X.columns).mean(axis=0).sort_values(ascending=False).reset_index()
imp.shape
# Out:
# (83, 2)

# %%
imp = imp[:82]
imp_list = list(imp['index'])

# %%
df = df[imp_list]
df.shape
df.head(2)
# Out:
# (7467, 82)
#                     region        city  total/mean_square_type  \
# 275299    Красноярскийкрай  Красноярск                0.234467
# 275300  Саратовскаяобласть     Саратов                0.484887
#
#         osm_catering_points_in_0.005 osm_city_nearest_name  total_square  \
# 275299                             0            Красноярск    106.351104
# 275300                            44               Саратов    175.039602
#
#         osm_catering_points_in_0.001  street floor  \
# 275299                             0   S5845     G
# 275300                             4  S27968     G
#
#         reform_mean_floor_count_500  osm_city_nearest_population  \
# 275299                     7.612903                    1095286.0
# 275300                     4.164557                     842097.0
#
#         osm_subway_closest_dist  osm_catering_points_in_0.01  mean_group_type  \
# 275299                 1.087101                            2       453.587238
# 275300               357.425239                           89       360.990435
#
#         osm_crossing_points_in_0.005 realty_type  total/mean_square_city  \
# 275299                             6           C                0.343528
# 275300                             4           A                0.640103
#
#         osm_amenity_points_in_0.01  osm_culture_points_in_0.005  \
# 275299                          26                            0
# 275300                         462                            1
#
#         osm_crossing_closest_dist  osm_transport_stop_closest_dist  \
# 275299                   0.041323                         0.052809
# 275300                   0.144936                         0.045451
#
#         reform_mean_year_building_500  osm_hotels_points_in_0.0075  \
# 275299                    1980.483871                            0
# 275300                    1939.348837                            5
#
#         osm_amenity_points_in_0.001  osm_hotels_points_in_0.005  \
# 275299                            0                           0
# 275300                           13                           2
#
#         osm_transport_stop_points_in_0.0075  min_group_reg  \
# 275299                                   15       5.840220
# 275300                                   34      14.977634
#
#         osm_hotels_points_in_0.01  total/mean_square_reg  \
# 275299                          0               0.345297
# 275300                          7               0.649276
#
#         osm_city_closest_dist  osm_transport_stop_points_in_0.01  \
# 275299               7.795659                                 21
# 275300               0.987160                                 45
#
#         osm_catering_points_in_0.0075  osm_train_stop_points_in_0.0075  \
# 275299                              0                                0
# 275300                             66                                0
#
#         osm_amenity_points_in_0.0075  osm_historic_points_in_0.0075  \
# 275299                            14                              0
# 275300                           345                              7
#
#         mean_group_city  osm_healthcare_points_in_0.0075  \
# 275299       309.585190                                0
# 275300       273.455334                               17
#
#         osm_offices_points_in_0.0075  osm_shops_points_in_0.001  \
# 275299                             0                          0
# 275300                            21                          8
#
#         osm_culture_points_in_0.0075  min_group_city  \
# 275299                             0        5.840220
# 275300                             6       14.977634
#
#         osm_shops_points_in_0.0075  reform_mean_year_building_1000  \
# 275299                          10                     1976.684211
# 275300                         218                     1940.591549
#
#         osm_shops_points_in_0.005  osm_train_stop_closest_dist  \
# 275299                          5                     2.281425
# 275300                        125                     1.924421
#
#         reform_mean_floor_count_1000  osm_crossing_points_in_0.01  \
# 275299                      7.136842                           35
# 275300                      4.144608                           59
#
#         osm_building_points_in_0.005  osm_culture_points_in_0.001  \
# 275299                             0                            0
# 275300                             0                            0
#
#         max_group_reg  osm_shops_points_in_0.01  reform_house_population_1000  \
# 275299    8081.034585                        15                        2670.0
# 275300    1622.896787                       286                        4886.0
#
#         osm_leisure_points_in_0.01  osm_crossing_points_in_0.0075  \
# 275299                           1                             25
# 275300                          20                             34
#
#         osm_healthcare_points_in_0.01  reform_house_population_500  \
# 275299                              0                        940.0
# 275300                             27                        943.0
#
#         osm_crossing_points_in_0.001  osm_historic_points_in_0.01  \
# 275299                             2                            1
# 275300                             0                            9
#
#         osm_culture_points_in_0.01  reform_count_of_houses_1000  \
# 275299                           2                           95
# 275300                           9                          502
#
#         osm_amenity_points_in_0.005  osm_historic_points_in_0.005  \
# 275299                            7                             0
# 275300                          198                             4
#
#         osm_finance_points_in_0.0075  osm_finance_points_in_0.001  \
# 275299                             2                            0
# 275300                            22                            0
#
#         osm_transport_stop_points_in_0.005  osm_offices_points_in_0.001  \
# 275299                                   7                            0
# 275300                                  22                            1
#
#         osm_leisure_points_in_0.0075  osm_finance_points_in_0.005  \
# 275299                             1                            1
# 275300                            16                           13
#
#         min_group_type  osm_building_points_in_0.0075  \
# 275299        5.845197                              0
# 275300        5.734575                              0
#
#         reform_count_of_houses_500  osm_finance_points_in_0.01  \
# 275299                          31                           3
# 275300                         104                          27
#
#         osm_offices_points_in_0.01  osm_offices_points_in_0.005  \
# 275299                           0                            0
# 275300                          28                           11
#
#         mean_group_reg  osm_train_stop_points_in_0.01  \
# 275299      307.998704                              0
# 275300      269.592184                              0
#
#         osm_building_points_in_0.01  osm_healthcare_points_in_0.005  \
# 275299                            0                               0
# 275300                            0                               7
#
#         max_group_city  osm_leisure_points_in_0.005  \
# 275299     8081.034585                            1
# 275300     1622.896787                           11
#
#         osm_train_stop_points_in_0.005  osm_building_points_in_0.001
# 275299                               0                             0
# 275300                               0                             0

# %% [markdown]
# ##  5. Прогнозирование таргета<a id="5"></a>
# [Оглавление▲▲](#heading)

# %%
cat_col = df.select_dtypes(include=['object']).columns.to_list()
num_col = df.select_dtypes(exclude=['object']).columns.to_list()

# %%
train = df[mask]
test = df[~mask]

# %%
train.head(2)
# Out:
#                     region        city  total/mean_square_type  \
# 275299    Красноярскийкрай  Красноярск                0.234467
# 275300  Саратовскаяобласть     Саратов                0.484887
#
#         osm_catering_points_in_0.005 osm_city_nearest_name  total_square  \
# 275299                             0            Красноярск    106.351104
# 275300                            44               Саратов    175.039602
#
#         osm_catering_points_in_0.001  street floor  \
# 275299                             0   S5845     G
# 275300                             4  S27968     G
#
#         reform_mean_floor_count_500  osm_city_nearest_population  \
# 275299                     7.612903                    1095286.0
# 275300                     4.164557                     842097.0
#
#         osm_subway_closest_dist  osm_catering_points_in_0.01  mean_group_type  \
# 275299                 1.087101                            2       453.587238
# 275300               357.425239                           89       360.990435
#
#         osm_crossing_points_in_0.005 realty_type  total/mean_square_city  \
# 275299                             6           C                0.343528
# 275300                             4           A                0.640103
#
#         osm_amenity_points_in_0.01  osm_culture_points_in_0.005  \
# 275299                          26                            0
# 275300                         462                            1
#
#         osm_crossing_closest_dist  osm_transport_stop_closest_dist  \
# 275299                   0.041323                         0.052809
# 275300                   0.144936                         0.045451
#
#         reform_mean_year_building_500  osm_hotels_points_in_0.0075  \
# 275299                    1980.483871                            0
# 275300                    1939.348837                            5
#
#         osm_amenity_points_in_0.001  osm_hotels_points_in_0.005  \
# 275299                            0                           0
# 275300                           13                           2
#
#         osm_transport_stop_points_in_0.0075  min_group_reg  \
# 275299                                   15       5.840220
# 275300                                   34      14.977634
#
#         osm_hotels_points_in_0.01  total/mean_square_reg  \
# 275299                          0               0.345297
# 275300                          7               0.649276
#
#         osm_city_closest_dist  osm_transport_stop_points_in_0.01  \
# 275299               7.795659                                 21
# 275300               0.987160                                 45
#
#         osm_catering_points_in_0.0075  osm_train_stop_points_in_0.0075  \
# 275299                              0                                0
# 275300                             66                                0
#
#         osm_amenity_points_in_0.0075  osm_historic_points_in_0.0075  \
# 275299                            14                              0
# 275300                           345                              7
#
#         mean_group_city  osm_healthcare_points_in_0.0075  \
# 275299       309.585190                                0
# 275300       273.455334                               17
#
#         osm_offices_points_in_0.0075  osm_shops_points_in_0.001  \
# 275299                             0                          0
# 275300                            21                          8
#
#         osm_culture_points_in_0.0075  min_group_city  \
# 275299                             0        5.840220
# 275300                             6       14.977634
#
#         osm_shops_points_in_0.0075  reform_mean_year_building_1000  \
# 275299                          10                     1976.684211
# 275300                         218                     1940.591549
#
#         osm_shops_points_in_0.005  osm_train_stop_closest_dist  \
# 275299                          5                     2.281425
# 275300                        125                     1.924421
#
#         reform_mean_floor_count_1000  osm_crossing_points_in_0.01  \
# 275299                      7.136842                           35
# 275300                      4.144608                           59
#
#         osm_building_points_in_0.005  osm_culture_points_in_0.001  \
# 275299                             0                            0
# 275300                             0                            0
#
#         max_group_reg  osm_shops_points_in_0.01  reform_house_population_1000  \
# 275299    8081.034585                        15                        2670.0
# 275300    1622.896787                       286                        4886.0
#
#         osm_leisure_points_in_0.01  osm_crossing_points_in_0.0075  \
# 275299                           1                             25
# 275300                          20                             34
#
#         osm_healthcare_points_in_0.01  reform_house_population_500  \
# 275299                              0                        940.0
# 275300                             27                        943.0
#
#         osm_crossing_points_in_0.001  osm_historic_points_in_0.01  \
# 275299                             2                            1
# 275300                             0                            9
#
#         osm_culture_points_in_0.01  reform_count_of_houses_1000  \
# 275299                           2                           95
# 275300                           9                          502
#
#         osm_amenity_points_in_0.005  osm_historic_points_in_0.005  \
# 275299                            7                             0
# 275300                          198                             4
#
#         osm_finance_points_in_0.0075  osm_finance_points_in_0.001  \
# 275299                             2                            0
# 275300                            22                            0
#
#         osm_transport_stop_points_in_0.005  osm_offices_points_in_0.001  \
# 275299                                   7                            0
# 275300                                  22                            1
#
#         osm_leisure_points_in_0.0075  osm_finance_points_in_0.005  \
# 275299                             1                            1
# 275300                            16                           13
#
#         min_group_type  osm_building_points_in_0.0075  \
# 275299        5.845197                              0
# 275300        5.734575                              0
#
#         reform_count_of_houses_500  osm_finance_points_in_0.01  \
# 275299                          31                           3
# 275300                         104                          27
#
#         osm_offices_points_in_0.01  osm_offices_points_in_0.005  \
# 275299                           0                            0
# 275300                          28                           11
#
#         mean_group_reg  osm_train_stop_points_in_0.01  \
# 275299      307.998704                              0
# 275300      269.592184                              0
#
#         osm_building_points_in_0.01  osm_healthcare_points_in_0.005  \
# 275299                            0                               0
# 275300                            0                               7
#
#         max_group_city  osm_leisure_points_in_0.005  \
# 275299     8081.034585                            1
# 275300     1622.896787                           11
#
#         osm_train_stop_points_in_0.005  osm_building_points_in_0.001
# 275299                               0                             0
# 275300                               0                             0

# %%
scaler = MinMaxScaler()
train[num_col] = scaler.fit_transform(train[num_col])
test[num_col] = scaler.transform(test[num_col])
train.shape, y.shape
# Out:
# ((4493, 82), (4493,))

# %%
x_train, x_valid, y_train, y_valid = train_test_split(train, y, test_size=0.25, random_state=42)
x_train.shape, y_train.shape
x_valid.shape, y_valid.shape
# Out:
# ((3369, 82), (3369,))
# ((1124, 82), (1124,))

# %%
cat = CatBoostRegressor(random_state=42)
cat.fit(X=x_train, y=y_train, eval_set=(x_valid, y_valid), cat_features=cat_col, verbose=0)
cat.get_best_score()
# Out:
# {'learn': {'RMSE': 0.1678279476773571},
#  'validation': {'RMSE': 0.3169910479315357}}

# %%
cat.fit(X=train, y=y, cat_features=cat_col, verbose=0)
pred = np.exp(cat.predict(test))

# %%
test_1['per_square_meter_price'] = pred
test_1[['id','per_square_meter_price']]

# %%
test_1['per_square_meter_price'].hist(bins=100);

# %% [markdown]
# ####  обрежем "верхний край данных" от выбросов

# %%
test_1.loc[test_1['per_square_meter_price']>=150000, 'per_square_meter_price'] = \
test_1.loc[test_1['per_square_meter_price']>=150000, 'per_square_meter_price'] * 0.85

# %%
final = test_1[['id','per_square_meter_price']]
final.to_csv('sub.csv', index=False)
